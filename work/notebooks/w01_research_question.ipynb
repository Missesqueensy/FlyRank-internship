# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Missesqueensy/FlyRank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""Growth / Recovery / Momentum Prediction"""
# Out:
# 'Growth / Recovery / Momentum Prediction'

# %%
# %cd /content

# !git clone https://github.com/Missesqueensy/FlyRank-internship.git

# %cd FlyRank-internship

# !ls
# Out:
# /content
# fatal: destination path 'FlyRank-internship' already exists and is not an empty directory.
# /content/FlyRank-internship
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""What decision does your work improve?

My work helps prioritize which content pages are most likely to lose or gain organic search traffic in the near future. This supports decisions about which pages should be optimized first
Who acts on it?

The primary users are SEO specialists, content managers, and digital marketing teams responsible for improving website performance
What does a wrong recommendation cost?

A wrong recommendation may cause the team to spend time and resources optimizing pages that are unlikely to benefit, while truly important pages continue losing visibility and traffic. This can reduce marketing efficiency and potentially decrease organic search performance"""
# Out:
# 'What decision does your work improve?\n\nMy work helps prioritize which content pages are most likely to lose or gain organic search traffic in the near future. This supports decisions about which pages should be optimized first\nWho acts on it?\n\nThe primary users are SEO specialists, content managers, and digital marketing teams responsible for improving website performance\nWhat does a wrong recommendation cost?\n\nA wrong recommendation may cause the team to spend time and resources optimizing pages that are unlikely to benefit, while truly important pages continue losing visibility and traffic. This can reduce marketing efficiency and potentially decrease organic search performance'

# %%
# !pwd
# !ls
# Out:
# /content/FlyRank-internship
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %%
import os

print("CSV files الموجودة:")
for root, dirs, files in os.walk("data"):
    for f in files:
        if f.endswith(".csv"):
            print(os.path.join(root, f))
# Out:
# CSV files الموجودة:
# data/raw/content_refresh_anonymized.csv

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("========== Dataset Summary ==========")

print(f"Number of pages: {len(df):,}")

print(f"Average CTR: {df['ctr'].mean():.2%}")

print(f"Average position: {df['avg_position'].mean():.2f}")

print("\nContent types:")
print(df["content_type"].value_counts())

print("\nTrend direction:")
print(df["trend_direction"].value_counts())
# Out:
# ========== Dataset Summary ==========
# Number of pages: 30,000
# Average CTR: 51.07%
# Average position: 16.34
#
# Content types:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64
#
# Trend direction:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
"""What my work can claim

This project identifies patterns and trends in historical search performance data.
The model provides decision support by estimating which content pages are more likely to grow, remain stable, or decline in future search visibility.
The recommendations should be interpreted as evidence-based priorities rather than certain outcomes"""
"""What my work cannot claim

This project does not explain or reverse-engineer Google's ranking algorithm.
It does not prove that one ranking factor directly causes changes in search performance.
The predictions are probabilistic and should support human decision-making, not replace it"""

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
